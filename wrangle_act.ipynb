# %%
import pandas as pd
import numpy as np 
import requests
import os
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
import re
import matplotlib
import seaborn

# %% [markdown]
# # Data Gathering

# %%
#gathering first data

df_archive = pd.read_csv("twitter-archive-enhanced.csv")

# %%
#gather tsv fil by using sep
df_image = pd.read_csv("image-predictions.tsv", sep = "\t")

# %%
#create new folder with using url for tsv fil with mode web
url = ' https://video.udacity-data.com/topher/2018/November/5bf60c69_image-predictions-3/image-predictions-3.tsv'
file_name = url.split("/")[-1], mode = "wb"
response = requests.get(url)
if not os.path.exists(file_name):
    with open(file_name, "wb") as f:
        f.write(response.content)

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-f00ed1356639> in <module>()
#      17 # Twitter API code was sent to this student from a Udacity instructor
#      18 # Tweet IDs for which to gather additional data via Twitter's API
# ---> 19 tweet_ids = df_1.tweet_id.values
#      20 len(tweet_ids)
#      21
#
# NameError: name 'df_1' is not defined

# %%
#create folder with 3 column 
df_list = []


with open('tweet_json.txt', 'r') as file:
    for line in file:
        tweet = json.loads(line)
        tweet_id = tweet['id']
        retweet_count = tweet['retweet_count']
        fav_count = tweet['favorite_count']
        df_list.append({'tweet_id':tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': fav_count})
        
api_df = pd.DataFrame(df_list)

# %% [markdown]
# # Assessing Data

# %%
df_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_archive.head(4)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# ...

# %%
df_archive.tail(4)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# ...

# %%
df_archive.count()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           78
# in_reply_to_user_id             78
# timestamp                     2356
# source                        2356
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id       181
# retweeted_status_timestamp     181
# expanded_urls                 2297
# rating_numerator              2356
# rating_denominator            2356
# name                          2315
# dog_stage                      380
# dtype: int64

# %%
df_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2315 non-null object
# dog_stage                     380 non-null object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 257.8+ KB

# %%
df_image
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
df_image.head(4)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# ...

# %%
df_image.tail(4)
# Out:
#                 tweet_id                                          jpg_url  \
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog        p3   p3_conf  p3_dog
# 2071    True   spatula  0.040836   False
# 2072    True    kelpie  0.031379    True
# 2073    True  papillon  0.068957    True
# 2074   False    banana  0.076110   False

# %%
df_image.count()
# Out:
# tweet_id    2075
# jpg_url     2075
# img_num     2075
# p1          2075
# p1_conf     2075
# p1_dog      2075
# p2          2075
# p2_conf     2075
# p2_dog      2075
# p3          2075
# p3_conf     2075
# p3_dog      2075
# dtype: int64

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
api_df
# Out:
#       favorite_count  retweet_count            tweet_id
# 0              39467           8853  892420643555336193
# 1              33819           6514  892177421306343426
# 2              25461           4328  891815181378084864
# 3              42908           8964  891689557279858688
# 4              41048           9774  891327558926688256
# 5              20562           3261  891087950875897856
# 6              12041           2158  890971913173991426
# 7              56848          16716  890729181411237888
# 8              28226           4429  890609185150312448
# 9              32467           7711  890240255349198849
# 10             31166           7624  890006608113172480
# 11             28268           5156  889880896479866881
# 12             38818           8538  889665388333682689
# 13             27672           4735  889638837579907072
# 14             15359           2321  889531135344209921
# 15             25652           5637  889278841981685760
# ...

# %%
api_df.head()
# Out:
#    favorite_count  retweet_count            tweet_id
# 0           39467           8853  892420643555336193
# 1           33819           6514  892177421306343426
# 2           25461           4328  891815181378084864
# 3           42908           8964  891689557279858688
# 4           41048           9774  891327558926688256

# %%
api_df.tail()
# Out:
#       favorite_count  retweet_count            tweet_id
# 2349             111             41  666049248165822465
# 2350             311            147  666044226329800704
# 2351             128             47  666033412701032449
# 2352             132             48  666029285002620928
# 2353            2535            532  666020888022790149

# %%
api_df.count()
# Out:
# favorite_count    2354
# retweet_count     2354
# tweet_id          2354
# dtype: int64

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# favorite_count    2354 non-null int64
# retweet_count     2354 non-null int64
# tweet_id          2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %% [markdown]
# ## Quality
#
# ### df_archive :
#
# - Missing data and records in (in replay to status id - in replay to user id - retweeted status id - retweeted status user id - retweeted status timestamp
# - Sometimes in (name) column has value like (an – a ) however the correct names in text column
#
# - Has misspelling like  (doggopuppo - doggofloofer – doggopupper)
# - (Tweet id) column is integer not object
#
#
# ### Df_image
#
# - Nondescriptive column headers (p1-p2—p3- p1 conf-  p2 conf- p3_conf- p1_dog - p2_dog -p3_dog)
# - Some photos not related to breed of dogs and this show in (p1_dog , p2_dog  , p3_dog )column with False value
# - We have some data max between capitalization and lowercase  in (p1 - p2- p3)
#
#  ### df_api
#
# - change (retweet_count and favorite _count ) to be object type

# %% [markdown]
# ## Tidy
#
# - calssification (doggo - floofer - pupper - puppo)
# - T

# %% [markdown]
# # clean

# %%
df_archive_clean = df_archive.copy()

# %%
df_image_clean = df_image.copy()

# %%
api_df_clean =api_df.copy()

# %% [markdown]
# Define
# - Some photos not related to breed of dogs and this show in (p1_dog , p2_dog , p3_dog )column with False value so i drop it

# %% [markdown]
# code

# %%
df_image_clean = df_image_clean[df_image_clean['p1_dog'] == True]
df_image_clean = df_image_clean[df_image_clean['p2_dog'] == True]
df_image_clean = df_image_clean[df_image_clean['p3_dog'] == True]

# %% [markdown]
# Test

# %%
df_image_clean.p1_dog
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 19      True
# 20      True
# 23      True
# 24      True
# 26      True
# 27      True
# 28      True
# 30      True
# 31      True
# 32      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
#         ...
# 2034    True
# 2035    True
# 2036    True
# 2037    True
# 2038    True
# 2039    True
# 2040    True
# 2042    True
# 2043    True
# 2045    True
# 2047    True
# 2049    True
# 2051    True
# 2053    True
# 2054    True
# 2055    True
# 2056    True
# 2057    True
# 2058    True
# 2059    True
# 2060    True
# 2061    True
# 2062    True
# 2064    True
# 2065    True
# 2066    True
# 2067    True
# 2070    True
# 2072    True
# 2073    True
# Name: p1_dog, Length: 1243, dtype: bool

# %% [markdown]
# Define

# %% [markdown]
# *Nondescriptive column headers (p1-p2- p3 - p1 conf - p2 conf- p3_conf- p1_dog  -p2_dog - p3_dog) rename it (p1: Prediction_1 ,p1_conf :Confidence_1,p1_dog: Breed_1 and so on )

# %% [markdown]
# Code

# %%
#rename columns
df_image_clean = df_image_clean.rename(columns={"p1" :"Prediction_1","p1_conf":"Confidence_1",'p1_dog':"Breed_1",
                          "p2":"Prediction_2","p2_conf":"Confidence_2",'p2_dog':"Breed_2",
                          "p3":"Prediction_3","p3_conf":"Confidence_3",'p3_dog':"Breed_3" })

# %% [markdown]
# Test

# %%
list(df_image_clean)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'Prediction_1',
#  'Confidence_1',
#  'Breed_1',
#  'Prediction_2',
#  'Confidence_2',
#  'Breed_2',
#  'Prediction_3',
#  'Confidence_3',
#  'Breed_3']

# %% [markdown]
# define
#
# * The data has max between  lowercase and capital in P1 - P2 and p3 so i will change it to be capitalize ()

# %% [markdown]
# Code

# %%
#capitalize the data
df_image_clean['Prediction_1'] = df_image_clean['Prediction_1'].str.capitalize()
df_image_clean['Prediction_2'] = df_image_clean['Prediction_2'].str.capitalize()
df_image_clean['Prediction_3'] = df_image_clean['Prediction_3'].str.capitalize()

# %% [markdown]
# Test

# %%
df_image_clean['Prediction_1'].head(4)
# Out:
# 0    Welsh_springer_spaniel
# 1                   Redbone
# 2           German_shepherd
# 3       Rhodesian_ridgeback
# Name: Prediction_1, dtype: object

# %%
df_image_clean['Prediction_2'].head(4)
# Out:
# 0                Collie
# 1    Miniature_pinscher
# 2              Malinois
# 3               Redbone
# Name: Prediction_2, dtype: object

# %%
df_image_clean['Prediction_3'].tail(4)
# Out:
# 2067                       Pembroke
# 2070    German_short-haired_pointer
# 2072                         Kelpie
# 2073                       Papillon
# Name: Prediction_3, dtype: object

# %% [markdown]
# define
# - name column have error (a - an) so we will take the name from text

# %% [markdown]
# code

# %%
#make new copy from data 

df_archive_c2 = df_archive_clean.copy()

#mention any name less than 3 lens in name column

#pattern_2 = re.compile(r'(?:name(?:d)?)\s{1}(?:is\s)?([A-Za-z]+)')
#for index, row in df_archive_c2.iterrows():  
 #   if len(row['name']) < 3 and row['name'][0].islower():
  #      print(row['name'])

# %%
#change the less than 3 len to be the name which in text column 

pattern_2 = re.compile(r'(?:name(?:d)?)\s{1}(?:is\s)?([A-Za-z]+)')
for index, row in df_archive_c2.iterrows():  
    try:
        if row['name'] == "a":
            c_name = re.findall(pattern_2, row['text'])[0]
            df_archive_clean.loc[index,'name'] = df_archive_clean.loc[index,'name'].replace('a', c_name)
        elif row['name'] == 'an':
            c_name = re.findall(pattern_2, row['text'])[0]
            df_archive_clean.loc[index,'name'] = df_archive_clean.loc[index,'name'].replace('an', c_name)
    except IndexError:
        df_archive_clean.loc[index,'name'] = np.nan

            
df_archive_clean.name.value_counts(dropna = False)
# Out:
# None       745
# NaN         41
# Charlie     12
# Oliver      11
# Lucy        11
# Cooper      11
# Lola        10
# Penny       10
# Tucker      10
# Bo           9
# Winston      9
# Sadie        8
# the          8
# Toby         7
# Daisy        7
# Buddy        7
# Bailey       7
# Jax          6
# Leo          6
# Koda         6
# Stanley      6
# Bella        6
# Scout        6
# Dave         6
# Rusty        6
# Milo         6
# Oscar        6
# Jack         6
# Bentley      5
# Larry        5
#           ...
# Alf          1
# BeBe         1
# all          1
# Sonny        1
# Rupert       1
# Ralpher      1
# Benny        1
# Mollie       1
# Bert         1
# Chaz         1
# my           1
# Eugene       1
# Julius       1
# Creg         1
# Jimbo        1
# Remy         1
# Roscoe       1
# Geno         1
# Andy         1
# Tanner       1
# Mookie       1
# Rinna        1
# Robin        1
# Sweets       1
# Walker       1
# Boston       1
# Kody         1
# ...

# %% [markdown]
# test

# %%
df_archive_clean.name
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
# 5           None
# 6            Jax
# 7           None
# 8           Zoey
# 9         Cassie
# 10          Koda
# 11         Bruno
# 12          None
# 13           Ted
# 14        Stuart
# 15        Oliver
# 16           Jim
# 17          Zeke
# 18       Ralphus
# 19        Canela
# 20        Gerald
# 21       Jeffrey
# 22          such
# 23        Canela
# 24          None
# 25          None
# 26          Maya
# 27        Mingus
# 28         Derek
# 29        Roscoe
#           ...
# 2326       quite
# 2327         NaN
# 2328        None
# 2329        None
# 2330        None
# 2331        None
# 2332        None
# 2333         NaN
# 2334         NaN
# 2335         NaN
# 2336        None
# 2337        None
# 2338        None
# 2339        None
# 2340        None
# 2341        None
# 2342        None
# 2343        None
# 2344        None
# 2345         the
# 2346         the
# ...

# %% [markdown]
# Test

# %%
df_archive_clean.name.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
# 5           None
# 6            Jax
# 7           None
# 8           Zoey
# 9         Cassie
# 10          Koda
# 11         Bruno
# 12          None
# 13           Ted
# 14        Stuart
# 15        Oliver
# 16           Jim
# 17          Zeke
# 18       Ralphus
# 19        Canela
# 20        Gerald
# 21       Jeffrey
# 22          such
# 23        Canela
# 24          None
# 25          None
# 26          Maya
# 27        Mingus
# 28         Derek
# 29        Roscoe
#           ...
# 2326       quite
# 2327         NaN
# 2328        None
# 2329        None
# 2330        None
# 2331        None
# 2332        None
# 2333         NaN
# 2334         NaN
# 2335         NaN
# 2336        None
# 2337        None
# 2338        None
# 2339        None
# 2340        None
# 2341        None
# 2342        None
# 2343        None
# 2344        None
# ...

# %% [markdown]
# define
# - replace doggopuppo - doggofloofer - doggopupper to (doggo - puppo) and etc
# - replace none in doggo - floofer - pupper -puppo columns

# %% [markdown]
# code

# %%
#replace the missspeling in dog of ages 
df_archive_clean.iloc[:, -4:  ] = df_archive_clean.iloc[:, -4:  ].replace('None','')
df_archive_clean.iloc[:, -4:  ] = df_archive_clean.iloc[:, -4:  ].replace('doggopupper','doggo-pupper')
df_archive_clean.iloc[:, -4:  ] = df_archive_clean.iloc[:, -4:  ].replace('doggofloofer','doggo-floofer')
df_archive_clean.iloc[:, -4:  ] = df_archive_clean.iloc[:, -4:  ].replace("doggopuppo","doggo-puppo")

# %% [markdown]
# test

# %%
df_archive_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# Define
# - change tweet id from int to object in 3 data to make merge

# %% [markdown]
# code

# %%
#change the type of tweetid to be object 
df_archive_clean['tweet_id'] = df_archive_clean['tweet_id'].astype(object)

# %%
df_image_clean['tweet_id'] = df_image_clean['tweet_id'].astype(object)

# %%
api_df_clean['tweet_id'] = api_df_clean['tweet_id'].astype(object)

# %% [markdown]
# test

# %%
df_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2315 non-null object
# dog_stage                     380 non-null object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 257.8+ KB

# %%
df_image_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1243 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id        1243 non-null object
# jpg_url         1243 non-null object
# img_num         1243 non-null int64
# Prediction_1    1243 non-null object
# Confidence_1    1243 non-null float64
# Breed_1         1243 non-null bool
# Prediction_2    1243 non-null object
# Confidence_2    1243 non-null float64
# Breed_2         1243 non-null bool
# Prediction_3    1243 non-null object
# Confidence_3    1243 non-null float64
# Breed_3         1243 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 100.8+ KB

# %%
api_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# favorite_count    2354 non-null int64
# retweet_count     2354 non-null int64
# tweet_id          2354 non-null object
# dtypes: int64(2), object(1)
# memory usage: 55.2+ KB

# %% [markdown]
# defin
#
# - Missing data and record in (in replay to status id - in replay to user id - retweeted status id - retweeted status user id  - retweeted status timestamp  ) thats why i will droped

# %%
# drop the retweets
df_archive_clean = df_archive_clean[pd.isnull(df_archive_clean.retweeted_status_id)]

# drop columns which have missing value
df_archive_clean = df_archive_clean.drop('retweeted_status_id', axis = 1)
df_archive_clean = df_archive_clean.drop('retweeted_status_user_id', 1)
df_archive_clean = df_archive_clean.drop('retweeted_status_timestamp', 1)

# Delete duplicated tweet_id
df_archive_clean = df_archive_clean.drop_duplicates()

# Delete tweets with no pictures
df_archive_clean = df_archive_clean.dropna(subset = ['jpg_url'])

#Delete dog_stage duplicates
df_archive_clean = df_archive_clean.sort_values('dog_stage').drop_duplicates('tweet_id', keep = 'last')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-290-3f156f628e55> in <module>()
#      14
#      15 # Delete tweets with no pictures
# ---> 16 df_archive_clean = df_archive_clean.dropna(subset = ['jpg_url'])
#      17
#      18 #Delete dog_stage duplicates
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['jpg_url']

# %%
df_archive_clean.drop(['timestamp', 'retweeted_status_timestamp'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-292-da749a1c3acc> in <module>()
# ----> 1 df_archive_clean.drop(['timestamp', 'retweeted_status_timestamp'], axis = 1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %% [markdown]
# Define
# - change data type to be object

# %%
df_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 11 columns):
# tweet_id                 2175 non-null object
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null object
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_numerator         2175 non-null int64
# rating_denominator       2175 non-null int64
# name                     2135 non-null object
# dog_stage                344 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 203.9+ KB

# %% [markdown]
# code

# %%
#change the type of tweetid to be object 
api_df_clean['favorite_count'] = api_df_clean['favorite_count'].astype(object)
api_df_clean['retweet_count'] = api_df_clean['retweet_count'].astype(object)

# %%
api_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# favorite_count    2354 non-null object
# retweet_count     2354 non-null object
# tweet_id          2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %% [markdown]
# ## Tidy

# %% [markdown]
# Define
# - we have 4 dolumns for dog stage so i create a new column to add the 4 values in one  and drop the 4 columns by using drop funcation

# %% [markdown]
# code

# %%
#add 4 columns in one column only called dog stage

dog_stage = df_archive_clean['doggo'] + df_archive_clean['floofer'] + df_archive_clean['pupper'] + df_archive_clean['puppo']

#add new column for dog stage

df_archive_clean['dog_stage'] = dog_stage
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'doggo'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-296-49c4ead1c5ed> in <module>()
# ...

# %%
#drop 4 columns 
df_archive_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'],axis =1 , inplace =True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-298-1f4b51c2ae38> in <module>()
#       1 #drop 4 columns
# ----> 2 df_archive_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'],axis =1 , inplace =True)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %% [markdown]
# Test

# %%
df_archive_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_archive_clean.dog_stage.value_counts()
# Out:
# pupper           224
# doggo             75
# puppo             24
# doggo-pupper      10
# floofer            9
# doggo-puppo        1
# doggo-floofer      1
# Name: dog_stage, dtype: int64

# %% [markdown]
# define
# -

# %% [markdown]
# code

# %%
prediction = []
confidence = []

def get_prediction_confidence(dataframe):
    if dataframe['Breed_1'] == True:
        prediction.append(dataframe['Prediction_1'])
        confidence.append(dataframe['Confidence_1'])
    elif dataframe['Breed_2'] == True:
        prediction.append(dataframe['Prediction_2'])
        confidence.append(dataframe['Confidence_2'])
    elif dataframe['Breed_3'] == True:
        prediction.append(dataframe['Prediction_3'])
        confidence.append(dataframe['Confidence_3'])
    else:
        prediction.append('NaN')
        confidence.append(0)

df_image_clean.apply(get_prediction_confidence, axis=1)
df_image_clean['prediction'] = prediction
df_image_clean['confidence'] = confidence

# %% [markdown]
# Test

# %%
df_image_clean
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11    666071193221509120    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 12    666073100786774016    https://pbs.twimg.com/media/CT5d9DZXAAALcwe.jpg
# 13    666082916733198337    https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
# ...

# %% [markdown]
# Merge data

# %%
df_prefinal = df_archive_clean.merge(api_df_clean, on='tweet_id', how='inner')

# %%
twitter_archive_master = df_image_clean.merge(df_prefinal, on = "tweet_id", how = "inner")

# %%
twitter_archive_master
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 7     666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 8     666071193221509120    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 9     666073100786774016    https://pbs.twimg.com/media/CT5d9DZXAAALcwe.jpg
# 10    666082916733198337    https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
# ...

# %% [markdown]
# # Storing

# %% [markdown]
# code
# - create new fil called twitter_archive_master.csv

# %%
# Save clean DataFrame to csv file
twitter_archive_master.drop(twitter_archive_master.columns[twitter_archive_master.columns.str.contains('Unnamed',case = False)],axis = 1)
twitter_archive_master.to_csv('twitter_archive_master.csv', encoding = 'utf-8', index=False)
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')

# %% [markdown]
# Test

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 26 columns):
# tweet_id                 1203 non-null int64
# jpg_url                  1203 non-null object
# img_num                  1203 non-null int64
# Prediction_1             1203 non-null object
# Confidence_1             1203 non-null float64
# Breed_1                  1203 non-null bool
# Prediction_2             1203 non-null object
# Confidence_2             1203 non-null float64
# Breed_2                  1203 non-null bool
# Prediction_3             1203 non-null object
# Confidence_3             1203 non-null float64
# Breed_3                  1203 non-null bool
# prediction               1203 non-null object
# confidence               1203 non-null float64
# in_reply_to_status_id    9 non-null float64
# in_reply_to_user_id      9 non-null float64
# timestamp                1203 non-null object
# source                   1203 non-null object
# ...

# %% [markdown]
# # Data Analyze visualizing

# %%
master_df.groupby(['breed']).retweet_count.mean().sort_values(ascending=False)[12::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-308-bf31c6748a72> in <module>()
# ----> 1 master_df.groupby(['breed']).retweet_count.mean().sort_values(ascending=False)[12::-1]
#
# NameError: name 'master_df' is not defined

# %%
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(['favorites','retweets'][twitter_archive_master].corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)
plt.title('Correlation Heat Map')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-309-940b0baa8787> in <module>()
# ----> 1 f,ax = plt.subplots(figsize=(12, 12))
#       2 sns.heatmap(['favorites','retweets'][twitter_archive_master].corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)
#       3 plt.title('Correlation Heat Map')
#
# NameError: name 'plt' is not defined

# %%
life_stage_count = list(twitter_archive_master[twitter_archive_master['dog_stage'] != 'None']['dog_stage'].value_counts())[0:4]
life_stages = twitter_archive_master[twitter_archive_master['dog_stage'] != 'None']['dog_stage'].value_counts().index.tolist()[0:4]
explode = (0.2, 0.1, 0.1, 0.1) 

figure1, axis1 = plt.subplots()
axis1.pie(dog_stage_count, explode = explode, labels = dog_stage, shadow = True, startangle = 90)
axis1.axis('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-310-a9f17fd68979> in <module>()
#       3 explode = (0.2, 0.1, 0.1, 0.1)
#       4
# ----> 5 figure1, axis1 = plt.subplots()
#       6 axis1.pie(dog_stage_count, explode = explode, labels = dog_stage, shadow = True, startangle = 90)
#       7 axis1.axis('equal')
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(twitter_archive_master['favorites'], twitter_archive_master['retweets'])
plt.xlabel('Favorites')
plt.ylabel('Retweets')
plt.title('Retweets and favorites Scatter plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-311-1f6e38f53bbf> in <module>()
# ----> 1 plt.scatter(twitter_archive_master['favorites'], twitter_archive_master['retweets'])
#       2 plt.xlabel('Favorites')
#       3 plt.ylabel('Retweets')
#       4 plt.title('Retweets and favorites Scatter plot')
#
# NameError: name 'plt' is not defined
